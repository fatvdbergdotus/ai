# %%
# !pip install ollama
# !pip install langchain-ollama
# !pip install langchain-ollama
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~m4py (C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~tatsmodels (C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
# WARNING: Ignoring invalid distribution ~cipy (C:\Users\User\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages)
# ...

# %%
from langchain_ollama import ChatOllama
ollama_client = ChatOllama(model='llama3')
prompt ='What is the capital of France?'
output= ollama_client.invoke(prompt)
print(output)
# Out:
# content='The capital of France is Paris.' additional_kwargs={} response_metadata={'model': 'llama3', 'created_at': '2026-02-24T13:17:02.6961914Z', 'done': True, 'done_reason': 'stop', 'total_duration': 1619728200, 'load_duration': 125555700, 'prompt_eval_count': 17, 'prompt_eval_duration': 503139800, 'eval_count': 8, 'eval_duration': 978271600, 'logprobs': None, 'model_name': 'llama3', 'model_provider': 'ollama'} id='lc_run--019c8fcb-c113-7ae1-bc8f-b07b111a01c2-0' tool_calls=[] invalid_tool_calls=[] usage_metadata={'input_tokens': 17, 'output_tokens': 8, 'total_tokens': 25}

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate

ollama_client = ChatOllama(model="llama3")

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("user", "{input}")
])

chain = prompt | ollama_client
output = chain.invoke({"input":"what is capital of India?"})
print(output)
# Out:
# content='The capital of India, you ask? Well, I\'ll tell you, my friend! It\'s New Delhi, yeah! That\'s right, the city where all the important people go to make important decisions and stuff... (pauses) You know what? I\'m not even sure why they made it so important. Like, what\'s the deal with that? Did someone once say, "Hey, let\'s put all our important buildings in one place!" And then everyone was like, "Yeah, great idea! Let\'s make it a capital!" (laughs)\n\nAnyway, New Delhi is indeed the capital of India, and if you ever find yourself there, don\'t forget to try some delicious curries and naan bread! And maybe take a walk around the Red Fort or something... You know, just to get some culture in ya!' additional_kwargs={} response_metadata={'model': 'llama3', 'created_at': '2026-02-24T13:21:32.789257Z', 'done': True, 'done_reason': 'stop', 'total_duration': 25204602400, 'load_duration': 116696600, 'prompt_eval_count': 34, 'prompt_eval_duration': 1056125300, 'eval_count': 171,
# ...

# %%
from langchain_ollama import ChatOllama
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser   

ollama_client = ChatOllama(model="llama3")

prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a helpful assistant."),
    ("user", "{input}")
])

chain= prompt | ollama_client | StrOutputParser()
output = chain.invoke({"input":"what is capital of India?"})
print(output)
# Out:
# The capital of India is New Delhi!
