# %%
import ollama

res = ollama.chat(
    model="llama3.2-vision",
    messages=[{
        "role": "user",
        "content": "Describe this image",
        "images": ["./Logo.png"]
    }]
)

print(res["message"]["content"])
# Out:
# models=[Model(model='llama3:latest', modified_at=datetime.datetime(2026, 2, 23, 11, 10, 38, 261032, tzinfo=TzInfo(0)), digest='365c0bd3c000a25d28ddbf732fe1c6add414de7275464c4e4d1c3b5fcb5d8ad1', size=4661224676, details=ModelDetails(parent_model='', format='gguf', family='llama', families=['llama'], parameter_size='8.0B', quantization_level='Q4_0'))]
# ---------------------------------------------------------------------------
# ResponseError                             Traceback (most recent call last)
# Cell In[4], line 4
#       2 ollama_client = Client(host='http://localhost:11434')
#       3 print(ollama_client.list())
# ----> 4 output= ollama_client.chat(model='llama3.2-vision:latest', messages=[
#       5     {
#       6         "role": "user",
#       7         "content": "Describe the below image",
#       8         "images": ['./Logo.png']
#       9     },
#      10 ])
#      11 print(output['message']['content'])
#
# ...
