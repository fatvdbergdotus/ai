# %% [markdown]
# # Linear Regression

# %% [markdown]
# Let's fabricate some data that shows a roughly linear relationship between page speed and amount purchased:

# %%
# %matplotlib inline
import numpy as np
from pylab import *

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.1, 1000)) * 3

scatter(pageSpeeds, purchaseAmount)

# %% [markdown]
# As we only have two features, we can keep it simple and just use scipy.state.linregress:

# %%
# !pip install scipy
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)
# Out:
# [notice] A new release of pip is available: 23.2.1 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting scipy
#   Obtaining dependency information for scipy from https://files.pythonhosted.org/packages/aa/7d/43ab67228ef98c6b5dd42ab386eae2d7877036970a0d7e3dd3eb47a0d530/scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata
#   Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl.metadata (60 kB)
# Requirement already satisfied: numpy<2.3,>=1.23.5 in c:\users\user\desktop\administration\udemy\mlcourse\pythonproject\.venv\lib\site-packages (from scipy) (2.2.0)
# Using cached scipy-1.14.1-cp312-cp312-win_amd64.whl (44.5 MB)
# Installing collected packages: scipy
# Successfully installed scipy-1.14.1

# %% [markdown]
# Not surprisngly, our R-squared value shows a really good fit:

# %%
r_value ** 2
# Out:
# np.float64(0.9898458213236714)

# %% [markdown]
# Let's use the slope and intercept we got from the regression to plot predicted values vs. observed:

# %%
import matplotlib.pyplot as plt

def predict(x):
    return slope * x + intercept

plt.scatter(pageSpeeds, purchaseAmount)
plt.plot(pageSpeeds, predict(pageSpeeds), c='r')
plt.show()

# %% [markdown]
# ## Activity

# %% [markdown]
# Try increasing the random variation in the test data, and see what effect it has on the r-squared error value.

# %%
# %matplotlib inline
import numpy as np
from pylab import *

pageSpeeds = np.random.normal(3.0, 1.0, 1000)
purchaseAmount = 100 - (pageSpeeds + np.random.normal(0, 0.3, 1000)) * 3

scatter(pageSpeeds, purchaseAmount)

# %%
slope, intercept, r_value, p_value, std_err = stats.linregress(pageSpeeds, purchaseAmount)
r_value ** 2
# Out:
# np.float64(0.9201226797236535)
